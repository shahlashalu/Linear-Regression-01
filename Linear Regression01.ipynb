# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/datascience/Machine Learning/MACHINE LEARNING ALGORITHMS/LINEAR REGRESSION/Real estate.csv')
df
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
df.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   No                                      414 non-null    int64
#  1   X1 transaction date                     414 non-null    float64
#  2   X2 house age                            414 non-null    float64
#  3   X3 distance to the nearest MRT station  414 non-null    float64
#  4   X4 number of convenience stores         414 non-null    int64
#  5   X5 latitude                             414 non-null    float64
#  6   X6 longitude                            414 non-null    float64
#  7   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 26.0 KB

# %%
df.shape
# Out:
# (414, 8)

# %%
df.isna().any()
# Out:
# X1 transaction date                       False
# X2 house age                              False
# X3 distance to the nearest MRT station    False
# X4 number of convenience stores           False
# X5 latitude                               False
# X6 longitude                              False
# Y house price of unit area                False
# dtype: bool

# %%
df['Y house price of unit area'].unique()
# Out:
# array([ 37.9,  42.2,  47.3,  54.8,  43.1,  32.1,  40.3,  46.7,  18.8,
#         22.1,  41.4,  58.1,  39.3,  23.8,  34.3,  50.5,  70.1,  37.4,
#         42.3,  47.7,  29.3,  51.6,  24.6,  47.9,  38.8,  27. ,  56.2,
#         33.6,  47. ,  57.1,  25. ,  34.2,  49.3,  55.1,  27.3,  22.9,
#         25.3,  46.2,  15.9,  18.2,  34.7,  34.1,  53.9,  38.3,  42. ,
#         61.5,  13.4,  13.2,  44.2,  20.7,  38.9,  51.7,  13.7,  41.9,
#         53.5,  22.6,  42.4,  21.3,  63.2,  27.7,  55. ,  44.3,  50.7,
#         56.8,  36.2,  59. ,  40.8,  36.3,  20. ,  54.4,  29.5,  36.8,
#         25.6,  29.8,  26.5,  48.1,  17.7,  43.7,  50.8,  18.3,  48. ,
#         45.4,  43.2,  21.8,  16.1,  41. ,  51.8,  59.5,  34.6,  51. ,
#         62.2,  38.2,  32.9,  45.7,  30.5,  71. ,  47.1,  26.6,  28.4,
#         39.4,  23.1,   7.6,  53.3,  46.4,  12.2,  13. ,  30.6,  59.6,
#         31.3,  32.5,  45.5,  57.4,  48.6,  62.9,  60.7,  37.5,  30.7,
# ...

# %%
df.describe()
# Out:
#                No  X1 transaction date  X2 house age  \
# count  414.000000           414.000000    414.000000
# mean   207.500000          2013.148971     17.712560
# std    119.655756             0.281967     11.392485
# min      1.000000          2012.667000      0.000000
# 25%    104.250000          2012.917000      9.025000
# 50%    207.500000          2013.167000     16.100000
# 75%    310.750000          2013.417000     28.150000
# max    414.000000          2013.583000     43.800000
#
#        X3 distance to the nearest MRT station  \
# count                              414.000000
# mean                              1083.885689
# std                               1262.109595
# min                                 23.382840
# 25%                                289.324800
# 50%                                492.231300
# 75%                               1454.279000
# max                               6488.021000
#
# ...

# %%
corr_matrix = df.corr()['Y house price of unit area']
corr_matrix
# Out:
# No                                       -0.028587
# X1 transaction date                       0.087491
# X2 house age                             -0.210567
# X3 distance to the nearest MRT station   -0.673613
# X4 number of convenience stores           0.571005
# X5 latitude                               0.546307
# X6 longitude                              0.523287
# Y house price of unit area                1.000000
# Name: Y house price of unit area, dtype: float64

# %%
df = df.drop(['No'], axis = 1)

# %%
df
# Out:
#      X1 transaction date  X2 house age  \
# 0               2012.917          32.0
# 1               2012.917          19.5
# 2               2013.583          13.3
# 3               2013.500          13.3
# 4               2012.833           5.0
# ..                   ...           ...
# 409             2013.000          13.7
# 410             2012.667           5.6
# 411             2013.250          18.8
# 412             2013.000           8.1
# 413             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# 4                                 390.56840                                5
# ...

# %%
#drop duplicates
df = df.drop_duplicates()
df
# Out:
#      X1 transaction date  X2 house age  \
# 0               2012.917          32.0
# 1               2012.917          19.5
# 2               2013.583          13.3
# 3               2013.500          13.3
# 4               2012.833           5.0
# ..                   ...           ...
# 409             2013.000          13.7
# 410             2012.667           5.6
# 411             2013.250          18.8
# 412             2013.000           8.1
# 413             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# 4                                 390.56840                                5
# ...

# %%
x = df.iloc[:,:6]
y = df.iloc[:,-1]

x.head()
# Out:
#    X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# 0             2012.917          32.0                                84.87882
# 1             2012.917          19.5                               306.59470
# 2             2013.583          13.3                               561.98450
# 3             2013.500          13.3                               561.98450
# 4             2012.833           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245

# %%
y.head()
# Out:
# 0    37.9
# 1    42.2
# 2    47.3
# 3    54.8
# 4    43.1
# Name: Y house price of unit area, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.20,random_state = 0)

# %%
x_train.head()
# Out:
#      X1 transaction date  X2 house age  \
# 302             2013.500          16.5
# 20              2013.417           4.5
# 303             2013.500          38.3
# 142             2013.417          19.8
# 14              2013.500          13.2
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 302                               2288.0110                                3
# 20                                2275.8770                                3
# 303                                439.7105                                0
# 142                                640.6071                                5
# 14                                1164.8380                                4
#
#      X5 latitude  X6 longitude
# 302     24.95885     121.51359
# 20      24.96314     121.51151
# 303     24.97161     121.53423
# 142     24.97017     121.54647
# 14      24.99156     121.53406

# %%
y_train.head()
# Out:
# 302    23.2
# 20     29.3
# 303    38.4
# 142    37.5
# 14     34.3
# Name: Y house price of unit area, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()

regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)

y_pred
# Out:
# array([40.09548022, 12.83819172, 42.00966923, 12.64733002, 42.44343803,
#        39.83198984, 40.55595745, 33.86023762, 49.37328265, 45.87031976,
#        45.86310332, 40.64517161, 39.50676203, 40.04955455, 47.11860745,
#        38.13995857, 40.08417262, 41.12540438, 40.83964717, 42.37860913,
#        49.70003677, 31.08231285, 39.67622569, 45.52764709, 46.18872415,
#        43.43143246, 46.35880414, 26.20749681, 48.13688227, 21.53997799,
#        44.8104349 , 34.94131598, 42.6644548 , 38.37379621, 43.98018394,
#        32.28477958, 47.62406077, 39.77407301, 52.55712201,  7.46443039,
#        52.54110472, 33.1285138 , 34.22107416, 49.59242876, 15.37567885,
#        43.36042455, 42.40643117, 12.9983919 , 33.99155573, 48.50179814,
#        53.67150141, 38.73047082, 47.73879852, 25.42163729, 30.68691477,
#        34.27187582, 48.91161249, 40.61983209, 43.45816985, 32.95307348,
#        43.85237072, 43.62659423, 39.55165632, 47.0209757 , 36.84017788,
# ...

# %%
y1_pred = regressor.predict(x_train)

y1_pred
# Out:
# array([31.38629584, 35.16286065, 33.3588218 , 41.96827853, 45.59685932,
#        53.55980992, 47.33219919, 40.29202246, 43.21028365, 32.67515728,
#        33.47995873, 23.61231482, 39.735908  , 34.48069852, 43.73612676,
#        16.55316558, 45.74127785, 41.12540438, 40.00124488, 41.47631687,
#        42.35381314, 40.2925378 , 29.1203836 , 43.39148644,  9.22731374,
#        44.66579954, 15.3053815 , 45.25036683, 42.66672208, 33.04036916,
#        42.26835353, 47.84572317, 37.4833148 , 47.67019562, 39.65917685,
#        37.20242728, 30.69192542, 36.21548711, 37.96205583, 31.86306825,
#        44.39468217, 49.72635003, 45.26345396, 53.28112371, 49.04340019,
#        16.58022436, 44.35319921, 39.4610734 , 54.56665741, 50.48079217,
#        28.18658458, 33.38278568, 16.1542282 , 40.59097697, 39.49935562,
#        50.17666402, 46.94182149, 41.20371161, 36.154976  , 46.33973612,
#        39.54568084, 44.82983093, 37.14880436, 50.50221124, 37.3875867 ,
# ...

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test,y_pred)

print("MSC: ",mse)
# Out:
# MSC:  59.522435319026265

# %%
training_score = regressor.score(x_train,y_train)
training_score
# Out:
# 0.5648053492261595

# %%
testing_score = regressor.score(x_test,y_test)
testing_score
# Out:
# 0.6573242742217953

# %%
y_result = regressor.predict([[415, 2018.91,45.0,69.87882,1524.98298,121.54024]])
print(y_result)
# Out:
# [329801.11748537]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
